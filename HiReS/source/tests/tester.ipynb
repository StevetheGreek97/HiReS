# %%
from HiReS.anno.ops import filter_touching_edges, unify, write_annotations_to_txt
from HiReS.anno.parser import AnnotationParser
import glob
from pathlib import Path

# %%
txt_path = glob.glob('/home/steve/Desktop/for_tmr/runs/segment/predict/labels/*.txt')
for txt in txt_path:
    anns = list(AnnotationParser(str(txt)).parse())
    filtered = filter_touching_edges(anns, threshold= 0.005)
    write_annotations_to_txt(filtered, str( '/home/steve/Desktop/for_tmr/tou/' + Path(txt).name), include_conf=True)

# %%
for i in parser.parse():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 for i in parser.parse():
#       2     print(i)
#
# File ~/exp/lib/python3.12/site-packages/HiReS/anno/parser.py:30, in AnnotationParser.parse(self)
#      28     yield from self._cached_annotations
#      29 else:
# ---> 30     parsed = [self._extract_data(line.strip().split()) for line in self._read_valid_lines()]
#      31     self._cached_annotations = [ann for ann in parsed if ann is not None]
#      32     yield from self._cached_annotations
#
# File ~/exp/lib/python3.12/site-packages/HiReS/anno/parser.py:38, in AnnotationParser._read_valid_lines(self)
#      37 def _read_valid_lines(self) -> List[str]:
# ---> 38     with open(self.txt_path, 'r') as file:
#      39         return [line for line in file if len(line.strip().split()) >= 3]
#
# ...
